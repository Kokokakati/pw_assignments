# %% [markdown]
# ![Screenshot 2024-02-11 at 8.28.40 PM.png](data:image/png;base64,...)

# %%
#1

import pandas as pd

# Load the dataset
flight_data = pd.read_csv('flight_price_dataset.csv')

# Examine dimensions of the dataset
print("Number of rows:", flight_data.shape[0])
print("Number of columns:", flight_data.shape[1])

# %%
#2
import matplotlib.pyplot as plt

# Create histogram
plt.hist(flight_data['Price'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Flight Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
#3
# Calculate range of prices
price_min = flight_data['Price'].min()
price_max = flight_data['Price'].max()

print("Minimum Price:", price_min)
print("Maximum Price:", price_max)
print("Price Range:", price_max - price_min)

# %%
#4
import seaborn as sns

# Create boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x='Airline', y='Price', data=flight_data)
plt.title('Flight Prices by Airline')
plt.xticks(rotation=45)
plt.xlabel('Airline')
plt.ylabel('Price')
plt.show()

# %%
#5
# Identify outliers using boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(flight_data['Price'])
plt.title('Identifying Outliers in Flight Prices')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# Potential Impact: Outliers may skew the mean and standard deviation of the dataset, leading to biased analysis. They may also affect the performance of certain machine learning algorithms that are sensitive to outliers.

# %% [markdown]
# 6. I would analyze the 'Date_of_Journey' feature to identify the peak travel season. By extracting the month from this feature, I can determine the months with the highest flight bookings. Additionally, I would consider factors such as 'Airline', 'Source', 'Destination', and 'Duration' to understand the preferences and trends of travelers during different seasons. I would present my findings using line plots or bar charts to visualize the number of flights booked per month or season, highlighting the peak travel periods.

# %% [markdown]
# 7. I would analyze the 'Date_of_Journey' feature to identify trends in flight prices over time. Additionally, I would examine the 'Airline', 'Source', 'Destination', 'Duration', and 'Total_Stops' features to understand how different factors affect flight prices. I would use line plots, scatter plots, and boxplots to visualize the relationship between these features and flight prices. For example, I could create line plots to show the average price of flights over time or boxplots to compare the distribution of prices for different airlines.

# %% [markdown]
# 8. I would analyze features such as 'Airline', 'Source', 'Destination', 'Duration', 'Total_Stops', and 'Additional_Info' to identify factors that affect flight prices. I would use statistical analysis techniques such as correlation analysis or regression analysis to quantify the relationship between these features and flight prices. Additionally, I could use machine learning models such as random forests or gradient boosting to identify the most important features for predicting flight prices. I would present my findings to the management team using visualizations such as bar charts, heatmaps, or feature importance plots to highlight the factors that have the greatest impact on flight prices.
